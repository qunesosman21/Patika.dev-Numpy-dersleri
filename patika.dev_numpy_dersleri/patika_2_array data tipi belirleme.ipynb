# %%
import numpy as np

# %%
x=np.array([1,2,2,4.6]) # hepsi floata döner

# %%
x
# Out:
# array([1. , 2. , 2. , 4.6])

# %%
x=np.array([1,2,2,4.6], dtype="int32") 

# dtype kullanark istediğimiz veri tipine dönüşüm sağlayabiliriz.

# %%
x
# Out:
# array([1, 2, 2, 4], dtype=int32)

# %%
x=np.array([1,2,2,4.6], dtype="str") #hepsi stringe dönüşecek

# %%
x
# Out:
# array(['1', '2', '2', '4.6'], dtype='<U3')

# %%
x=np.array(["a"], dtype="int32") 

# a nın integer gösterimi olmadığı için hata verir.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f327c21e8e39> in <module>()
# ----> 1 x=np.array(["a"], dtype="int32")
#       2
#       3 # a nın integer gösterimi olmadığı için hata verir.
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
x=np.array(["5"], dtype="int32") 
# burda string olan ifadenin integer karşılığı olduğu için hata vermez

# %%
x
# Out:
# array([5], dtype=int32)

# %%
x=np.array(["4.2"] ,dtype="int32") # array'inin elemanı hangi veri tipine cast olur?
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-4f24dea1b263> in <module>()
# ----> 1 x=np.array(["4.2"] ,dtype="int32") # array'inin elemanı hangi veri tipine cast olur?
#
# ValueError: invalid literal for int() with base 10: '4.2'
