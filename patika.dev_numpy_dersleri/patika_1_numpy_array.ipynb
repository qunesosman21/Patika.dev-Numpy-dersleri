# %%
import numpy as np

# %%
x=np.array([1,2,3,4])

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y=np.array(["a","b","c"])

# %%
y
# Out:
# array(['a', 'b', 'c'], dtype='<U1')

# %%
# bütün integerler string e dönüştürülecek
z=np.array([1,2,"c"])

# %%
z
# Out:
# array(['1', '2', 'c'], dtype='<U21')

# %%
a=np.array([1,2,"5"])

# %%
a
# Out:
# array(['1', '2', '5'], dtype='<U21')

# %%
# bütün integerler float a dönüştürülecek
c=np.array([1,2,3,4.5])

# %%
c
# Out:
# array([1. , 2. , 3. , 4.5])

# %%
# bütün integerler ve floatlar stringe e dönüştürülecek
b=np.array([1,2,3,4.5,"2","c"])

# %%
b
# Out:
# array(['1', '2', '3', '4.5', '2', 'c'], dtype='<U32')
