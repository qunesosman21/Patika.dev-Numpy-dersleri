# %%
import numpy as np

# %% [markdown]
# # sorting

# %%
a = np.array([20,32,5,30,10])

# %%
a
# Out:
# array([20, 32,  5, 30, 10])

# %%
np.sort(a) # burada a yı sıralar ama güncellemez
# Out:
# array([ 5, 10, 20, 30, 32])

# %%
a
# Out:
# array([20, 32,  5, 30, 10])

# %%
a.sort() # a' yı sıralar ve günceller

# %%
a # güncel a
# Out:
# array([ 5, 10, 20, 30, 32])

# %% [markdown]
# #Argsort

# %%
a = np.array([3,1,6,5,4,2])

# %%
# küçükten büyüpe sıralar elemanların indexsini verir
idxs = np.argsort(a)

# %%
idxs
# Out:
# array([1, 5, 0, 4, 3, 2])

# %%
a.argsort()
# Out:
# array([1, 5, 0, 4, 3, 2])

# %%
a
# Out:
# array([3, 1, 6, 5, 4, 2])
