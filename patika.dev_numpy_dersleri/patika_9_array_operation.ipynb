# %%
import numpy as np

# %%
a= [1,2,3]
b=[2,4,8]

a*b 

# işlemler listelerde tanımlı değil o yüzdwen hata verir.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-aba4679d7e57> in <module>()
#       2 b=[2,4,8]
#       3
# ----> 4 a*b
#       5
#       6 # işlemler listelerde tanımlı değil o yüzdwen hata verir.
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
[2,4,8] * 3
# Out:
# [2, 4, 8, 2, 4, 8, 2, 4, 8]

# %%
x=np.array([1,2,3])
y=np.array([2,4,8])

x*y

# aynı sayoda elemanları olması gerekiyor
# Out:
# array([ 2,  8, 24])

# %%
x2=np.array([1,2,3])
y2=np.array([2,4,8,9])

x2 * y2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-2bcf4fb82a8d> in <module>()
#       2 y2=np.array([2,4,8,9])
#       3
# ----> 4 x2 * y2
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
a= [1,2,3]
b=[2,4,8]

# %%
a + b
# Out:
# [1, 2, 3, 2, 4, 8]

# %%
print(x)
print(y)
# Out:
# [1 2 3]
# [2 4 8]

# %%
x + y
# Out:
# array([ 3,  6, 11])

# %%
x
# Out:
# array([1, 2, 3])

# %%
3 * x
# Out:
# array([3, 6, 9])

# %%
x = x * 3

# %%
x
# Out:
# array([3, 6, 9])

# %%
np.array([3,5,9])*3
# Out:
# array([ 9, 15, 27])
